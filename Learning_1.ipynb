# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('covid_19_dataset.csv')
df
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 71690      ZWE    Africa     Zimbabwe  2/23/2021      35910.0       48.0
# 71691      ZWE    Africa     Zimbabwe  2/24/2021      35960.0       50.0
# 71692      ZWE    Africa     Zimbabwe  2/25/2021      35994.0       34.0
# 71693      ZWE    Africa     Zimbabwe  2/26/2021      36044.0       50.0
# 71694      ZWE    Africa     Zimbabwe  2/27/2021      36058.0       14.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71695 entries, 0 to 71694
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               71695 non-null  object
#  1   continent                              68133 non-null  object
#  2   location                               71695 non-null  object
#  3   date                                   71695 non-null  object
#  4   total_cases                            70734 non-null  float64
#  5   new_cases                              70732 non-null  float64
#  6   new_cases_smoothed                     69731 non-null  float64
#  7   total_deaths                           61666 non-null  float64
#  8   new_deaths                             61824 non-null  float64
#  9   new_deaths_smoothed                    69731 non-null  float64
# ...

# %%
df['total_deaths'].max()
# Out:
# 2525401.0

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3562
# location                                     0
# date                                         0
# total_cases                                961
# new_cases                                  963
# new_cases_smoothed                        1964
# total_deaths                             10029
# new_deaths                                9871
# new_deaths_smoothed                       1964
# total_cases_per_million                   1348
# new_cases_per_million                     1350
# new_cases_smoothed_per_million            2346
# total_deaths_per_million                 10403
# new_deaths_per_million                   10245
# new_deaths_smoothed_per_million           2346
# reproduction_rate                        14233
# icu_patients                             64082
# icu_patients_per_million                 64082
# hosp_patients                            62538
# ...

# %%
df['continent'].value_counts()
# Out:
# Africa           18842
# Europe           17343
# Asia             17160
# North America     8398
# South America     4373
# Oceania           2017
# Name: continent, dtype: int64

# %%
df['total_tests'].mean()
# Out:
# 4331077.532364353

# %% [markdown]
# The process of cleaning a messy data is called data munging or data wrungling.

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# iso_code                                 0
# continent                                0
# location                                 0
# date                                     0
# total_cases                              0
# new_cases                                0
# new_cases_smoothed                       0
# total_deaths                             0
# new_deaths                               0
# new_deaths_smoothed                      0
# total_cases_per_million                  0
# new_cases_per_million                    0
# new_cases_smoothed_per_million           0
# total_deaths_per_million                 0
# new_deaths_per_million                   0
# new_deaths_smoothed_per_million          0
# reproduction_rate                        0
# icu_patients                             0
# icu_patients_per_million                 0
# hosp_patients                            0
# hosp_patients_per_million                0
# weekly_icu_admissions                    0
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  7.169500e+04   71695.000000        71695.000000  7.169500e+04
# mean   5.953143e+05    5038.374991         4983.292047  1.568776e+04
# std    4.233942e+06   31998.946495        31529.961359  9.869319e+04
# min    0.000000e+00  -46076.000000        -1121.714000  0.000000e+00
# 25%    6.100000e+02       1.000000            4.286000  9.000000e+00
# 50%    7.089000e+03      53.000000           59.857000  1.210000e+02
# 75%    7.943050e+04     636.500000          641.500000  1.524000e+03
# max    1.137847e+08  879905.000000       738686.000000  2.525401e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  71695.000000         71695.000000             71695.000000
# mean     113.258972           111.955293              6960.958266
# std      671.454443           648.636404             13974.385185
# min    -1918.000000          -232.143000                 0.000000
# ...

# %%
sns.set()

sns.countplot('continent', data=df)
# Out:
# C:\Users\Azrin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sns.countplot('continent', hue='location', data=df)
# Out:
# C:\Users\Azrin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='continent', ylabel='count'>
