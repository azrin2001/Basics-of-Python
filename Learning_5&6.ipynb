# %%
import pandas as pd
import numpy as np
df=pd.read_csv('covid_19_dataset.csv')
df
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 71690      ZWE    Africa     Zimbabwe  2/23/2021      35910.0       48.0
# 71691      ZWE    Africa     Zimbabwe  2/24/2021      35960.0       50.0
# 71692      ZWE    Africa     Zimbabwe  2/25/2021      35994.0       34.0
# 71693      ZWE    Africa     Zimbabwe  2/26/2021      36044.0       50.0
# 71694      ZWE    Africa     Zimbabwe  2/27/2021      36058.0       14.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3562
# location                                     0
# date                                         0
# total_cases                                961
# new_cases                                  963
# new_cases_smoothed                        1964
# total_deaths                             10029
# new_deaths                                9871
# new_deaths_smoothed                       1964
# total_cases_per_million                   1348
# new_cases_per_million                     1350
# new_cases_smoothed_per_million            2346
# total_deaths_per_million                 10403
# new_deaths_per_million                   10245
# new_deaths_smoothed_per_million           2346
# reproduction_rate                        14233
# icu_patients                             64082
# icu_patients_per_million                 64082
# hosp_patients                            62538
# ...

# %% [markdown]
# # Converting type (str-date)

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df=pd.read_csv('covid_19_dataset.csv', parse_dates=['date'])
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('date', inplace=True)
df
# Out:
#            iso_code continent     location  total_cases  new_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan          1.0        1.0
# 2020-02-25      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          1.0        0.0
# ...             ...       ...          ...          ...        ...
# 2021-02-23      ZWE    Africa     Zimbabwe      35910.0       48.0
# 2021-02-24      ZWE    Africa     Zimbabwe      35960.0       50.0
# 2021-02-25      ZWE    Africa     Zimbabwe      35994.0       34.0
# 2021-02-26      ZWE    Africa     Zimbabwe      36044.0       50.0
# 2021-02-27      ZWE    Africa     Zimbabwe      36058.0       14.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %% [markdown]
# # Cleaning & Handling messy data

# %%
#carrying forward from previous value
df=df.fillna(method='ffill')  #bfill for copying next value
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                    0
# location                                     0
# total_cases                                  0
# new_cases                                    0
# new_cases_smoothed                           5
# total_deaths                                27
# new_deaths                                  27
# new_deaths_smoothed                          5
# total_cases_per_million                      0
# new_cases_per_million                        0
# new_cases_smoothed_per_million               5
# total_deaths_per_million                    27
# new_deaths_per_million                      27
# new_deaths_smoothed_per_million              5
# reproduction_rate                           34
# icu_patients                              4186
# icu_patients_per_million                  4186
# hosp_patients                             4186
# hosp_patients_per_million                 4186
# ...

# %% [raw]
# #copy value from beside the same row
# df=df.fillna(method='ffill', axis='columns')
#
# #copy value forward only for once
# df=df.fillna(method='ffill',limit=1)

# %% [raw]
# #carrying a value by interpolòating the previous and next value
# new_df = df.interpolate()
# new_df = df.interpolate(mathod='time')

# %% [markdown]
# # Droping rows

# %%
new_df=df.dropna()
#new_df=df.dropna(how='all')   ##Only drop those rows which have no value in any columns
new_df
# Out:
#            iso_code continent  location  total_cases  new_cases  \
# date
# 2020-03-22      CYP    Europe    Cyprus         95.0       11.0
# 2020-03-23      CYP    Europe    Cyprus        116.0       21.0
# 2020-03-24      CYP    Europe    Cyprus        124.0        8.0
# 2020-03-25      CYP    Europe    Cyprus        132.0        8.0
# 2020-03-26      CYP    Europe    Cyprus        146.0       14.0
# ...             ...       ...       ...          ...        ...
# 2021-02-23      ZWE    Africa  Zimbabwe      35910.0       48.0
# 2021-02-24      ZWE    Africa  Zimbabwe      35960.0       50.0
# 2021-02-25      ZWE    Africa  Zimbabwe      35994.0       34.0
# 2021-02-26      ZWE    Africa  Zimbabwe      36044.0       50.0
# 2021-02-27      ZWE    Africa  Zimbabwe      36058.0       14.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-03-22               9.857           1.0         1.0                0.143
# ...

# %% [raw]
# #if we have atleast one non N/A valuse kepp that rows and drop all other rows
# new_df=df.dropna(thresh=1)
# new_df

# %% [markdown]
# # Inserting the missing dates

# %% [raw]
# dt=pd.date_range('2020-03-01','2021-12-31')
# idx=pd.DatetimeIndex(dt)
# x=new_df.reindex(idx)
# x

# %% [markdown]
# # Handling Missing Data

# %%
df
# Out:
#            iso_code continent     location  total_cases  new_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan          1.0        1.0
# 2020-02-25      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          1.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          1.0        0.0
# ...             ...       ...          ...          ...        ...
# 2021-02-23      ZWE    Africa     Zimbabwe      35910.0       48.0
# 2021-02-24      ZWE    Africa     Zimbabwe      35960.0       50.0
# 2021-02-25      ZWE    Africa     Zimbabwe      35994.0       34.0
# 2021-02-26      ZWE    Africa     Zimbabwe      36044.0       50.0
# 2021-02-27      ZWE    Africa     Zimbabwe      36058.0       14.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# ...

# %% [raw]
# x=df.replace([0.0,1.0],np.NaN)
# x

# %% [raw]
# #replace values based on specific columns
# x=df.replace({
#     'new_deaths':0.0,
#     'total_cases':1.0
# },np.NaN)
# x

# %%
x=df.replace('[A-Za-z]','',regex=True)
x
# Out:
#            iso_code continent location  total_cases  new_cases  \
# date
# 2020-02-24                                      1.0        1.0
# 2020-02-25                                      1.0        0.0
# 2020-02-26                                      1.0        0.0
# 2020-02-27                                      1.0        0.0
# 2020-02-28                                      1.0        0.0
# ...             ...       ...      ...          ...        ...
# 2021-02-23                                  35910.0       48.0
# 2021-02-24                                  35960.0       50.0
# 2021-02-25                                  35994.0       34.0
# 2021-02-26                                  36044.0       50.0
# 2021-02-27                                  36058.0       14.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-02-24                 NaN           NaN         NaN                  NaN
# ...

# %% [raw]
# y=df.replace({
#     'new_deaths':'[A-Za-z]',
#     'total_cases':'[A-Za-z]',
# },'',regex=True)
# y

# %% [markdown]
# # Replace the list value with another list

# %%
df=pd.DataFrame({
    'Student_Name':['Nakib','Azrin','Chaity','Zayed','Dany','Mouri'],
    'Remarks':['Exceptional','Average','Good','Very Poor','Average','Poor']
})
df
# Out:
#   Student_Name      Remarks
# 0        Nakib  Exceptional
# 1        Azrin      Average
# 2       Chaity         Good
# 3        Zayed    Very Poor
# 4         Dany      Average
# 5        Mouri         Poor

# %%
a=df.replace(['Poor','Very Poor','Average','Good','Exceptional'],[1,2,3,4,5])
a
# Out:
#   Student_Name  Remarks
# 0        Nakib        5
# 1        Azrin        3
# 2       Chaity        4
# 3        Zayed        2
# 4         Dany        3
# 5        Mouri        1
